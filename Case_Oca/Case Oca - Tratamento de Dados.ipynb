# %%
import pandas as pd
import numpy as np

# %%
df_oca=pd.read_excel('oca.xlsx',skiprows=2,skipfooter=23)

# %%
display(df_oca)
# Out:
#       Ano de exibição                                     Título da obra  \
# 0                2009                              007 Quantum of Solace
# 1                2009                                  1983.. O Ano Azul
# 2                2009  2 Filhos de Francisco: A História de Zezé Di C...
# 3                2009                                               2012
# 4                2009  23 Anos em 7 Segundos: 1977 - O Fim do Jejum C...
# ...               ...                                                ...
# 7578             2020                                       Volume Morto
# 7579             2020                                 Vou Nadar Até Você
# 7580             2020                                          Yesterday
# 7581             2020                                          Yomeddine
# 7582             2020                    Zootopia: Essa Cidade É O Bicho
#
#              CPB/ROE        Gênero   País(es) produtor(es) da obra  \
# ...

# %%
df_oca['Público no ano de exibição'].value_counts()
# Out:
# 40        26
# ND        25
# 6         23
# 5         21
# 14        21
#           ..
# 377922     1
# 8097       1
# 195772     1
# 3222       1
# 1529       1
# Name: Público no ano de exibição, Length: 5237, dtype: int64

# %%
df_oca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7583 entries, 0 to 7582
# Data columns (total 11 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Ano de exibição                  7583 non-null   int64
#  1   Título da obra                   7583 non-null   object
#  2   CPB/ROE                          7583 non-null   object
#  3   Gênero                           7583 non-null   object
#  4   País(es) produtor(es) da obra    7583 non-null   object
#  5   Nacionalidade da obra            7583 non-null   object
#  6   Data de lançamento               7583 non-null   object
#  7   Empresa distribuidora            7583 non-null   object
#  8   Origem da empresa distribuidora  7583 non-null   object
#  9   Público no ano de exibição       7583 non-null   object
#  10  Renda (R$) no ano de exibição    7583 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 651.8+ KB

# %%
df_oca['Data de lançamento'].value_counts()
# Out:
# Relançamento           207
# 2012-12-21 00:00:00     33
# 2015-12-03 00:00:00     33
# 2013-11-29 00:00:00     29
# 2018-11-15 00:00:00     29
#                       ...
# 2015-06-06 00:00:00      1
# 2015-04-18 00:00:00      1
# 2015-11-01 00:00:00      1
# 2007-12-28 00:00:00      1
# 2021-07-22 00:00:00      1
# Name: Data de lançamento, Length: 919, dtype: int64

# %%
df_oca.loc[df_oca['Data de lançamento']=='Relançamento'].head()
# Out:
#      Ano de exibição           Título da obra         CPB/ROE    Gênero  \
# 10              2009                 A agenda  E1600634500000    Ficção
# 248             2009            Fome de Viver  E1600228600000    Ficção
# 426             2009  Os Contos de Canterbury  E1600589800000    Ficção
# 474             2009              Ratatouille  E1500365600000  Animação
# 506             2009                Sofá Cama  E1600624100000    Ficção
#
#     País(es) produtor(es) da obra Nacionalidade da obra Data de lançamento  \
# 10                         França           Estrangeira       Relançamento
# 248                   Reino Unido           Estrangeira       Relançamento
# 426                        Itália           Estrangeira       Relançamento
# 474                Estados Unidos           Estrangeira       Relançamento
# 506                     Argentina           Estrangeira       Relançamento
#
#     Empresa distribuidora Origem da empresa distribuidora  \
# ...

# %%
df_oca['Data de lançamento']=pd.to_datetime(df_oca['Data de lançamento'],errors='coerce')

# %%
df_oca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7583 entries, 0 to 7582
# Data columns (total 11 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Ano de exibição                  7583 non-null   int64
#  1   Título da obra                   7583 non-null   object
#  2   CPB/ROE                          7583 non-null   object
#  3   Gênero                           7583 non-null   object
#  4   País(es) produtor(es) da obra    7583 non-null   object
#  5   Nacionalidade da obra            7583 non-null   object
#  6   Data de lançamento               7376 non-null   datetime64[ns]
#  7   Empresa distribuidora            7583 non-null   object
#  8   Origem da empresa distribuidora  7583 non-null   object
#  9   Público no ano de exibição       7583 non-null   object
#  10  Renda (R$) no ano de exibição    7583 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(9)
# ...

# %%
df_oca=df_oca.dropna(axis=0)

# %%
df_oca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7376 entries, 0 to 7582
# Data columns (total 11 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Ano de exibição                  7376 non-null   int64
#  1   Título da obra                   7376 non-null   object
#  2   CPB/ROE                          7376 non-null   object
#  3   Gênero                           7376 non-null   object
#  4   País(es) produtor(es) da obra    7376 non-null   object
#  5   Nacionalidade da obra            7376 non-null   object
#  6   Data de lançamento               7376 non-null   datetime64[ns]
#  7   Empresa distribuidora            7376 non-null   object
#  8   Origem da empresa distribuidora  7376 non-null   object
#  9   Público no ano de exibição       7376 non-null   object
#  10  Renda (R$) no ano de exibição    7376 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(9)
# ...

# %%
df_oca['Público no ano de exibição']=pd.to_numeric(df_oca['Público no ano de exibição'],errors='coerce')

# %%
df_oca['Renda (R$) no ano de exibição']=pd.to_numeric(df_oca['Renda (R$) no ano de exibição'],errors='coerce')

# %%
df_oca=df_oca.dropna(axis=0)
df_oca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7351 entries, 0 to 7582
# Data columns (total 11 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Ano de exibição                  7351 non-null   int64
#  1   Título da obra                   7351 non-null   object
#  2   CPB/ROE                          7351 non-null   object
#  3   Gênero                           7351 non-null   object
#  4   País(es) produtor(es) da obra    7351 non-null   object
#  5   Nacionalidade da obra            7351 non-null   object
#  6   Data de lançamento               7351 non-null   datetime64[ns]
#  7   Empresa distribuidora            7351 non-null   object
#  8   Origem da empresa distribuidora  7351 non-null   object
#  9   Público no ano de exibição       7351 non-null   float64
#  10  Renda (R$) no ano de exibição    7351 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(7)
# ...

# %%
import datetime as dt

# %%
df_oca['Ano de exibição'].value_counts()
# Out:
# 2015    748
# 2016    727
# 2018    688
# 2017    678
# 2019    664
# 2014    637
# 2009    579
# 2013    559
# 2011    554
# 2020    509
# 2010    506
# 2012    502
# Name: Ano de exibição, dtype: int64

# %%
teste1=pd.DataFrame(df_oca['Ano de exibição'].value_counts()).reset_index()

# %%
teste1.columns
# Out:
# Index(['index', 'Ano de exibição'], dtype='object')

# %%
teste1.sort_values(by='index',ascending=True)
# Out:
#     index  Ano de exibição
# 6    2009              579
# 10   2010              506
# 8    2011              554
# 11   2012              502
# 7    2013              559
# 5    2014              637
# 0    2015              748
# 1    2016              727
# 3    2017              678
# 2    2018              688
# 4    2019              664
# 9    2020              509

# %%
df_oca.sort_values(by='Renda (R$) no ano de exibição',ascending=False).head(1)
# Out:
#       Ano de exibição        Título da obra         CPB/ROE  Gênero  \
# 7048             2019  Vingadores: Ultimato  E1900107800000  Ficção
#
#      País(es) produtor(es) da obra Nacionalidade da obra Data de lançamento  \
# 7048                Estados Unidos           Estrangeira         2019-04-25
#
#      Empresa distribuidora Origem da empresa distribuidora  \
# 7048                Disney      Distribuição Internacional
#
#       Público no ano de exibição  Renda (R$) no ano de exibição
# 7048                  19656467.0                    338624881.0

# %%
df_oca.loc[df_oca['Renda (R$) no ano de exibição']==df_oca['Renda (R$) no ano de exibição'].max()]
# Out:
#       Ano de exibição        Título da obra         CPB/ROE  Gênero  \
# 7048             2019  Vingadores: Ultimato  E1900107800000  Ficção
#
#      País(es) produtor(es) da obra Nacionalidade da obra Data de lançamento  \
# 7048                Estados Unidos           Estrangeira         2019-04-25
#
#      Empresa distribuidora Origem da empresa distribuidora  \
# 7048                Disney      Distribuição Internacional
#
#       Público no ano de exibição  Renda (R$) no ano de exibição
# 7048                  19656467.0                    338624881.0

# %%
df_oca.sort_values(by='Renda (R$) no ano de exibição',ascending=False).head(5)
# Out:
#       Ano de exibição               Título da obra         CPB/ROE  Gênero  \
# 7048             2019         Vingadores: Ultimato  E1900107800000  Ficção
# 6860             2019                   O Rei Leão  E1900267700000  Ficção
# 6379             2018  Vingadores: Guerra Infinita  E1800067100000  Ficção
# 6572             2019                      Coringa  E1900357300000  Ficção
# 6544             2019                Capitã Marvel  E1900011200000  Ficção
#
#      País(es) produtor(es) da obra Nacionalidade da obra Data de lançamento  \
# 7048                Estados Unidos           Estrangeira         2019-04-25
# 6860                Estados Unidos           Estrangeira         2019-07-18
# 6379                Estados Unidos           Estrangeira         2018-04-26
# 6572        Canadá, Estados Unidos           Estrangeira         2019-10-03
# 6544                Estados Unidos           Estrangeira         2019-03-07
#
# ...

# %%
df_teste=df_oca.sort_values(by='Renda (R$) no ano de exibição',ascending=False)

# %%
display(df_teste.iloc[0:3])
# Out:
#       Ano de exibição               Título da obra         CPB/ROE  Gênero  \
# 7048             2019         Vingadores: Ultimato  E1900107800000  Ficção
# 6860             2019                   O Rei Leão  E1900267700000  Ficção
# 6379             2018  Vingadores: Guerra Infinita  E1800067100000  Ficção
#
#      País(es) produtor(es) da obra Nacionalidade da obra Data de lançamento  \
# 7048                Estados Unidos           Estrangeira         2019-04-25
# 6860                Estados Unidos           Estrangeira         2019-07-18
# 6379                Estados Unidos           Estrangeira         2018-04-26
#
#      Empresa distribuidora Origem da empresa distribuidora  \
# 7048                Disney      Distribuição Internacional
# 6860                Disney      Distribuição Internacional
# 6379                Disney      Distribuição Internacional
#
#       Público no ano de exibição  Renda (R$) no ano de exibição
# ...
